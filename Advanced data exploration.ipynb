# %% [markdown]
# # advanced data exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os

# %%
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'Movie-Rating.csv')

# %%
df
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
df.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
df.shape
# Out:
# (559, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
df.isnull().sum()
# Out:
# Film                         0
# Genre                        0
# Rotten Tomatoes Ratings %    0
# Audience Ratings %           0
# Budget (million $)           0
# Year of release              0
# dtype: int64

# %%
df.dtypes
# Out:
# Film                         object
# Genre                        object
# Rotten Tomatoes Ratings %     int64
# Audience Ratings %            int64
# Budget (million $)            int64
# Year of release               int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
df.columns=['Title','Genre','Criticrating','Audiencerating','Budgetinmillon','year']

# %%
df
# Out:
#                      Title      Genre  Criticrating  Audiencerating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      Budgetinmillon  year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
df.describe()
# Out:
#        Criticrating  Audiencerating  Budgetinmillon         year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Criticrating', 'Audiencerating', 'Budgetinmillon',
#        'year'],
#       dtype='object')

# %%
df['Genre']=df['Genre'].astype('category')
df['year']=df['year'].astype('category')   # is it real no. year you can take average,min,max but out come have no meaning

# %%
df.dtypes
# Out:
# Title               object
# Genre             category
# Criticrating         int64
# Audiencerating       int64
# Budgetinmillon       int64
# year              category
# dtype: object

# %%
vis=sns.jointplot(data=df,x='Criticrating',y='Audiencerating',kind='reg')

# %%
vis=sns.jointplot(data=df,x='Criticrating',y='Audiencerating',kind='hex')

# %%
plt.hist
# Out:
# <function matplotlib.pyplot.hist(x, bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, *, data=None, **kwargs)>

# %%
vis2=sns.distplot(df['Audiencerating'])

# %%
vis2=sns.distplot(df['Criticrating'])

# %%
sns.set_style('darkgrid')

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Criticrating', 'Audiencerating', 'Budgetinmillon',
#        'year'],
#       dtype='object')

# %%
vis3=sns.distplot(df['Audiencerating'],bins=16)

# %%
vis4 = plt.hist(df['Audiencerating'],bins=20)

# %%
sns.set_style('white')

# %%
vis3=plt.hist(df['Audiencerating'],bins=16)

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Criticrating', 'Audiencerating', 'Budgetinmillon',
#        'year'],
#       dtype='object')

# %%
plt.hist(df.Budgetinmillon)
plt.show()

# %%
plt.hist(df[df.Genre == 'Drama'].Budgetinmillon)
plt.xlabel('Budget (Millions)')
plt.ylabel('Frequency')
plt.title('Histogram of Budget for Drama Movies')
plt.show()

# %%
plt.hist(df[df.Genre == 'Action'].Budgetinmillon,bins = 20)
plt.hist(df[df.Genre == 'Thriller'].Budgetinmillon,bins = 20)
plt.hist(df[df.Genre == 'Drama']. Budgetinmillon,bins = 20)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist([df[df.Genre == 'Action'].Budgetinmillon,
         df[df.Genre == 'Thriller'].Budgetinmillon,
         df[df.Genre == 'Drama'].Budgetinmillon,
         df[df.Genre == 'Comedy'].Budgetinmillon],
         bins = 20,stacked = True)
plt.show()

# %%
for gen in df.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
df['Genre'].nunique()
# Out:
# 7

# %%
df['Genre'].value_counts()
# Out:
# Comedy       172
# Action       154
# Drama        101
# Horror        49
# Thriller      36
# Adventure     29
# Romance       18
# Name: Genre, dtype: int64

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Criticrating', 'Audiencerating', 'Budgetinmillon',
#        'year'],
#       dtype='object')

# %%
vis1 = sns.lmplot(data=df, x='Criticrating',y='Audiencerating',fit_reg =False)

# %%
vis2=sns.lmplot(data=df,x='Criticrating',y='Audiencerating',hue='Genre')

# %%
vis2=sns.lmplot(data=df,x='Criticrating',y='Audiencerating',hue='Genre',fit_reg=False)

# %%
vis2=sns.lmplot(data=df,x='Criticrating',y='Audiencerating',hue='Genre',fit_reg=False,aspect=1)

# %%
sns.regplot(data=df,x='Criticrating',y='Audiencerating',fit_reg=False)
# Out:
# <Axes: xlabel='Criticrating', ylabel='Audiencerating'>

# %%
k1 = sns.kdeplot(x=df.Criticrating, y=df.Audiencerating)

# %%
# %matplotlib inline

# %%
k1 = sns.kdeplot(x=df.Criticrating, y=df.Audiencerating,shade =True ,shade_lowest =False ,cmap='Reds')

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Criticrating', 'Audiencerating', 'Budgetinmillon',
#        'year'],
#       dtype='object')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(x=df.Budgetinmillon,y=df.Audiencerating)

# %%
f, ax = plt.subplots(1,2, figsize =(12,6))

# %%
f, axes = plt.subplots(1,2, figsize =(12,6))

k1 = sns.kdeplot(x=df.Budgetinmillon,y=df.Audiencerating,ax=axes[0])
k2 = sns.kdeplot(x=df.Budgetinmillon,y=df.Criticrating,ax = axes[1])

# %%
axes
# Out:
# array([<Axes: xlabel='Budgetinmillon', ylabel='Audiencerating'>,
#        <Axes: xlabel='Budgetinmillon', ylabel='Criticrating'>],
#       dtype=object)

# %%
w = sns.boxplot(data=df, x='Genre', y = 'Criticrating')

# %%
z = sns.violinplot(data=df, x='Genre', y = 'Criticrating')

# %%
w1 = sns.boxplot(data=df[df.Genre == 'Drama'], x='year', y = 'Criticrating')

# %%
z = sns.violinplot(data=df[df.Genre == 'Drama'], x='year', y = 'Criticrating')

# %%
g =sns.FacetGrid (df, row = 'Genre', col = 'year', hue = 'Genre')

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Criticrating', 'Audiencerating', 'Budgetinmillon',
#        'year'],
#       dtype='object')

# %%
plt.scatter(df.Criticrating,df.Audiencerating)

# %%
g =sns.FacetGrid (df, row = 'Genre', col = 'year', hue = 'Genre')
g = g.map(plt.scatter, 'Criticrating', 'Audiencerating' )

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Criticrating', 'Audiencerating', 'Budgetinmillon',
#        'year'],
#       dtype='object')

# %%
g =sns.FacetGrid (df, row = 'Genre', col = 'year', hue = 'Genre')
g = g.map(plt.hist, 'Budgetinmillon')

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Criticrating', 'Audiencerating', 'Budgetinmillon',
#        'year'],
#       dtype='object')

# %%
g =sns.FacetGrid (df, row = 'Genre', col = 'year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'Criticrating', 'Audiencerating',**kws )

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Criticrating', 'Audiencerating', 'Budgetinmillon',
#        'year'],
#       dtype='object')

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(x=df.Budgetinmillon,y=df.Audiencerating,ax=axes[0,0])
k2 = sns.kdeplot(x=df.Budgetinmillon,y=df.Criticrating,ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=df[df.Genre=='Drama'], x='year', y = 'Criticrating', ax=axes[1,0])

k4 = sns.kdeplot(x=df.Criticrating,y=df.Audiencerating,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(x=df.Criticrating, y=df.Audiencerating,cmap='Reds',ax = axes[1,1])

plt.show()

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Criticrating', 'Audiencerating', 'Budgetinmillon',
#        'year'],
#       dtype='object')

# %%
# How can you style your dashboard  using different color map

# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(x=df.Budgetinmillon,y=df.Audiencerating,
                 shade = True, shade_lowest=True,cmap = 'inferno',
                 ax = axes[0,0])
k1b = sns.kdeplot(x=df.Budgetinmillon, y=df.Audiencerating,
                 cmap = 'cool',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(x=df.Budgetinmillon,y=df.Criticrating,
                 shade=True, shade_lowest=True, cmap='inferno',
                 ax = axes[0,1])
k2b = sns.kdeplot(x=df.Budgetinmillon,y=df.Criticrating,
                  cmap = 'cool', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=df[df.Genre=='Drama'],
                   x='year', y = 'Criticrating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(x=df.Criticrating,y=df.Audiencerating, 
                 shade = True,shade_lowest=False,cmap='Blues_r',
                 ax=axes[1,1])

k4b = sns.kdeplot(x=df.Criticrating, y=df.Audiencerating, 
                  cmap='gist_gray_r',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()
